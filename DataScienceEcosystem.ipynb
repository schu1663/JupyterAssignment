# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystems

# %% [markdown]
# ## Author
# Danielle Schuler

# %% [markdown]
# In this notebook, data science tools and ecosystems will be summarized.

# %% [markdown]
# **Objectives**
# - List some popular languages used by data scientists
# - List some common libraries used by data scientists
# - List some common tools used by data scientists
# - Demonstrate how to evaluate arithmetic expressions using Python

# %% [markdown]
# Some of the popular languages that data scientists use are:
# 1. R
# 2. Python
# 3. C++

# %% [markdown]
# Some of the common librares used by data scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# | -------------------|
# | MongoDB |
# | Hadoop HDFS |
# | Apache Spark SQL |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expressions to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335
